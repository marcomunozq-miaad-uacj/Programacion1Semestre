# %% [markdown]
# <a href="https://colab.research.google.com/github/marcomunozq-miaad-uacj/Programacion1Semestre/blob/Programacion1Sem/Practica_13_Limpieza_y_Transformaci%C3%B3n_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practica 13-17. Gráficos de dispersión con plotly.express y el dataset gapminder
# Alumno: Marco Antonio Muñoz Quiroz
#
#
# El objetivo de esta actividad es que los estudiantes practiquen los temas vistos de carga de datos, normalización de nombres de columnas, separación y unión de columnas, errores en los tipos de datos. Todo es en un conjunto de datos utilizando Pandas en Python.
#
#
# https://github.com/marcomunozq-miaad-uacj/Programacion1Semestre/blob/315a199da2c21161514527e9bd3eec150210ba95/Practica_13_Limpieza_y_Transformaci%C3%B3n_de_Datos.ipynb

# %% [markdown]
# ## Práctica 13: Carga de Datos
#
# Al final del archivo contiene una línea que dice "Esta es una línea que no deberías cargar". Esta línea es irrelevante por lo tanto al cargar el CSV a un dataframe se debería de ignorar.
#
# Carga el archivo a un dataframe usando el código necesario para omitir la última fila.
# Usa df.tail(3) para demostrar que no has cargado la última línea
# Imprime la cantidad de filas y columnas del dataframe

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Semestre1/Programacion/Semana4/Practica13/miaad-nyc-r-s.csv'

with open(file_path, 'r', encoding='utf-8') as f:
    rows = f.readlines()
    total_rows = len(rows)

df = pd.read_csv(file_path, engine='python')
df.tail(1)
#Aqui si carga la ultima linea
# Out:
#                                      Unnamed: 0  BOROUGH NEIGHBORHOOD  \
# 84548  Esta es una línea que no deberías cargar      NaN         None
#
#       BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  LOT EASE-MENT  \
# 84548                    None                 None    NaN  NaN      None
#
#       BUILDING CLASS AT PRESENT ADDRESS  ... RESIDENTIAL UNITS  \
# 84548                      None    None  ...               NaN
#
#        COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 84548               NaN          NaN              None               None
#
#       YEAR BUILT TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 84548        NaN                       NaN                            None
#
#        SALE PRICE SALE DATE
# 84548        None      None
#
# [1 rows x 22 columns]

# %%
df = pd.read_csv(file_path, skipfooter=1, engine='python')
df.tail(1)
#Aqui ya no carga la ultima linea del csv original
# Out:
#        Unnamed: 0  BOROUGH NEIGHBORHOOD  \
# 84547        8413        5      WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT            ADDRESS  ...  \
# 84547   7105  679                                  P9  155 CLAY PIT ROAD  ...
#
#       RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 84547                 0                 1            1             10796
#
#        GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 84547               2400       2006                         4
#
#        BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 84547                              P9       69300  2016-10-27 00:00:00
#
# [1 rows x 22 columns]

# %%
print("Cantidad de filas y columnas:", df.shape)
#cantidad de filas y columnas totales
# Out:
# Cantidad de filas y columnas: (84548, 22)

# %% [markdown]
# ## Práctica 14: Agregar una columna
#
# Imprime los nombres de la columnas del archivo
# Asegúrate que el nombre de la primera columna debería ser INDEX MIIAD.
#
# Si esto no es así, entonces agrega dicho nombre a la columna y vuelve a imprimir los nombres para mostrar el cambio realizado.

# %%
print("La primer columna aparece como 'Unnamed: 0'\n")
print(df.columns)

if df.columns[0] != 'INDEX MIIAD':
    df.columns.values[0] = 'INDEX MIIAD'

print("\nAqui ya cambia a 'INDEX MIIAD'\n")
print(df.columns)
# Out:
# La primer columna aparece como 'Unnamed: 0'
#
# Index(['INDEX MIIAD', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')
#
# Aqui ya cambia a 'INDEX MIIAD'
#
# Index(['INDEX MIIAD', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
# ...

# %% [markdown]
# ## Práctica 15: Normalización de los nombres de la columna
#
# Normaliza los nombres de ls columnas, los cuales deberán estar en minúsculas.
#
# Asimismo, reemplaza los espacios con guion bajo
# Imprime los nombres de las columnas para demostrar que has realizado la normalización.

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

print("Nombres de columnas normalizados. Todos tienen guion bajo.\n")
print(df.columns)
# Out:
# Nombres de columnas normalizados. todos tienen guion bajo
#
# Index(['index_miiad', 'borough', 'neighborhood', 'building_class_category',
#        'tax_class_at_present', 'block', 'lot', 'ease-ment',
#        'building_class_at_present', 'address', 'apartment_number', 'zip_code',
#        'residential_units', 'commercial_units', 'total_units',
#        'land_square_feet', 'gross_square_feet', 'year_built',
#        'tax_class_at_time_of_sale', 'building_class_at_time_of_sale',
#        'sale_price', 'sale_date'],
#       dtype='object')

# %% [markdown]
# ## Práctica 16: Errores en los Tipos de Datos
#
# Imprime los tipos de datos de cada columna.
#
# Asegúrate que las columnas de SALE PRICE(sale_price), LAND SQUARE FEET (land_square_feet), GROSS SQUARE FEET (gross_square_feet) sean de tipo flotante.
#
# Escribe qué tipo de dato tienen asignado. Si no son correctos, realiza el cambio.
#
# Imprime de nuevo los tipos de datos para demostrar que has arreglado el problema.

# %%
print("Tipos de datos de todo el dataframe:\n")
print(df.dtypes)
# Out:
# Tipos de datos de todo el dataframe:
#
# index_miiad                        int64
# borough                            int64
# neighborhood                      object
# building_class_category           object
# tax_class_at_present              object
# block                              int64
# lot                                int64
# ease-ment                         object
# building_class_at_present         object
# address                           object
# apartment_number                  object
# zip_code                           int64
# residential_units                  int64
# commercial_units                   int64
# total_units                        int64
# land_square_feet                  object
# gross_square_feet                 object
# year_built                         int64
# tax_class_at_time_of_sale          int64
# building_class_at_time_of_sale    object
# sale_price                        object
# sale_date                         object
# ...

# %%
print("Tipos de datos antes de la conversion de las columnas en cuestion:\n")
print(df[['sale_price', 'land_square_feet', 'gross_square_feet']].dtypes)
# Out:
# Tipos de datos antes de la conversion de las columnas en cuestion:
#
# sale_price           object
# land_square_feet     object
# gross_square_feet    object
# dtype: object

# %%
columns_to_convert = ['sale_price', 'land_square_feet', 'gross_square_feet']

for col in columns_to_convert:
    df[col] = pd.to_numeric(df[col].astype(str).str.replace(',', ''), errors='coerce')

print("\nTipos de datos después de la conversion. Ahora son float64\n")
print(df[columns_to_convert].dtypes)
# Out:
# Tipos de datos después de la conversion. Ahora son float64
#
# sale_price           float64
# land_square_feet     float64
# gross_square_feet    float64
# dtype: object

# %% [markdown]
# Práctica 17: Genera el diccionario de datos del dataframe preprocesado. Imprime el contenido de dicho diccionario

# %%
# Vemos como quedo el dataframe al final de todas las modificaciones
df
# Out:
#        index_miiad  borough   neighborhood  \
# 0                4        1  ALPHABET CITY
# 1                5        1  ALPHABET CITY
# 2                6        1  ALPHABET CITY
# 3                7        1  ALPHABET CITY
# 4                8        1  ALPHABET CITY
# ...            ...      ...            ...
# 84543         8409        5        WOODROW
# 84544         8410        5        WOODROW
# 84545         8411        5        WOODROW
# 84546         8412        5        WOODROW
# 84547         8413        5        WOODROW
#
#                            building_class_category tax_class_at_present  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...

# %%
#Aqui generamos el diccionario y lo convertimos en dataframe
diccionario_datos = pd.DataFrame({"Nombre de la columna": df.columns,
                                  "Tipo de dato": [str(df[col].dtype) for col in df.columns]})
diccionario_datos
# Out:
#                  Nombre de columna Tipo de dato
# 0                      index_miiad        int64
# 1                          borough        int64
# 2                     neighborhood       object
# 3          building_class_category       object
# 4             tax_class_at_present       object
# 5                            block        int64
# 6                              lot        int64
# 7                        ease-ment       object
# 8        building_class_at_present       object
# 9                          address       object
# 10                apartment_number       object
# 11                        zip_code        int64
# 12               residential_units        int64
# 13                commercial_units        int64
# 14                     total_units        int64
# 15                land_square_feet      float64
# 16               gross_square_feet      float64
# 17                      year_built        int64
# 18       tax_class_at_time_of_sale        int64
# ...
